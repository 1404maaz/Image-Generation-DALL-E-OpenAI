# %% [markdown]
# <a href="https://colab.research.google.com/github/1404maaz/Image-Generation-DALL-E-OpenAI/blob/main/Image_Generation_DALL_E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import openai
import urllib.request
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

# %%
openai.api_key = "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"

# %%
img_response = openai.Image.create(
    prompt = 'panda enjoying a soup',
    n=1,
    size="512x512")

# %%
img_response
# Out:
# <OpenAIObject at 0x7bc646c426b0> JSON: {
#   "created": 1709374634,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-w78aYxo76NazsW7iNG9KC5l6/user-i7BrjJVFmnk2oVmQ1bUltZEA/img-Iw9kDCRJiCEyM2Mi97UYnFIM.png?st=2024-03-02T09%3A17%3A14Z&se=2024-03-02T11%3A17%3A14Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-01T23%3A36%3A49Z&ske=2024-03-02T23%3A36%3A49Z&sks=b&skv=2021-08-06&sig=TXkKuC7MB9qfC%2BQZ%2BAzXrKLpZDyQE9AwOcihsxip9lM%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-w78aYxo76NazsW7iNG9KC5l6/user-i7BrjJVFmnk2oVmQ1bUltZEA/img-Iw9kDCRJiCEyM2Mi97UYnFIM.png?st=2024-03-02T09%3A17%3A14Z&se=2024-03-02T11%3A17%3A14Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-01T23%3A36%3A49Z&ske=2024-03-02T23%3A36%3A49Z&sks=b&skv=2021-08-06&sig=TXkKuC7MB9qfC%2BQZ%2BAzXrKLpZDyQE9AwOcihsxip9lM%3D'

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-w78aYxo76NazsW7iNG9KC5l6/user-i7BrjJVFmnk2oVmQ1bUltZEA/img-Iw9kDCRJiCEyM2Mi97UYnFIM.png?st=2024-03-02T09%3A17%3A14Z&se=2024-03-02T11%3A17%3A14Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-03-01T23%3A36%3A49Z&ske=2024-03-02T23%3A36%3A49Z&sks=b&skv=2021-08-06&sig=TXkKuC7MB9qfC%2BQZ%2BAzXrKLpZDyQE9AwOcihsxip9lM%3D'

# %%
urllib.request.urlretrieve(img_url, 'img.png')
# Out:
# ('img.png', <http.client.HTTPMessage at 0x7bc612b9d840>)

# %%
img = cv2.imread("img.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
